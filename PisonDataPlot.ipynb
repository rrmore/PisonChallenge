# %%
# Obtain visualisation of data to get correlation. X axis is timestamp and Y is data. Red dot indicates active label
import time
import psutil
import matplotlib.pyplot as plt
import json
import ijson
import numpy as np
import matplotlib.ticker as ticker

# %%
# %matplotlib notebook
plt.rcParams['animation.html'] = 'jshtml'

# %%
fig = plt.figure()
ax = fig.add_subplot(111)
fig.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
# Stored part of the data stream in this file and used it to plot graph
F = open("MyFile.txt","r")

# %%
actX=[]
actY=[]
restX=[]
restY=[]
i=0
for line in F:
    y = json.loads(line)
    if(y['label']=='REST'):
        restX.append(y['timeStamp'])
        restY.append(y['data'])
    else:
        actX.append(y['timeStamp'])
        actY.append(y['data'])
    ax.scatter(actX,actY,marker='o',color='r')
    ax.scatter(restX,restY,marker='o',color='b')
    ax.yaxis.set_major_locator(ticker.MultipleLocator(3000))
    fig.canvas.draw()
    time.sleep(0.5)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-41-2d4cfa960b2b> in <module>()
#      15     ax.scatter(restX,restY,marker='o',color='b')
#      16     ax.yaxis.set_major_locator(ticker.MultipleLocator(3000))
# ---> 17     fig.canvas.draw()
#      18     time.sleep(0.5)
#      19
#
# ~\Anaconda3\lib\site-packages\matplotlib\backends\backend_webagg_core.py in draw(self)
#     159         backend_agg.RendererAgg.lock.acquire()
#     160         try:
# --> 161             self.figure.draw(renderer)
#     162         finally:
#     163             backend_agg.RendererAgg.lock.release()
#
# ~\Anaconda3\lib\site-packages\matplotlib\artist.py in draw_wrapper(artist, renderer, *args, **kwargs)
#      53                 renderer.start_filter()
#      54
# ---> 55             return draw(artist, renderer, *args, **kwargs)
#      56         finally:
# ...
